# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahira148/colab-git-assignment2/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name "Tahira148"
# !git config --global user.email "taheerakia14@gmail.com"
# Out:
# git version 2.34.1

# %%
# !git clone https://github.com/Tahira148/colab-git-assignment2.git
# Out:
# fatal: destination path 'colab-git-assignment2' already exists and is not an empty directory.

# %%
# !ls colab-git-assignment2
# Out:
# Assignment2.ipynb  colab-git-assignment2  README.md

# %%
# %cd colab-git-assignment2
# Out:
# /content/colab-git-assignment2/colab-git-assignment2

# %%
# %cd /content
# Out:
# /content

# %%
# !ls
# Out:
# Assignment2.ipynb  colab-git-assignment2  sample_data

# %% [markdown]
# #Git and GitHub Assignment 2
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b
print(multiply_numbers(3, 4))
# Out:
# 12

# %%
# !git add "Assignment2.ipynb"
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git commit -m "Add initial notebook with multiplication function"
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git remote set-url origin https://github.com/Tahira148/colab-git-assignment2.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git checkout -b feature-branch
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
def divide_numbers(a, b):
    if b != 0:
        return a / b
    else:
        return "Cannot divide by zero"

print(divide_numbers(10, 2))
# Out:
# 5.0

# %%
# !git add Assignment2.ipynb
# !git commit -m "Add initial notebook with multiplication function"
# Out:
# fatal: pathspec 'Assignment2.ipynb' did not match any files
# On branch feature-branch
# nothing to commit, working tree clean
